# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 4. Would you like a quick explanation or to see it in a different base?

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Three gods A, B, and C: one always tells the truth, one always lies, and one answers randomly. You do not know which god is which, and their language uses two words for yes and no: "da" and "ja," but you do not know which word means yes. You may ask yes/no questions, directed to any god, and you may base questions on prior answers. The random god answers randomly (not truthfully or lying consistently). What is the minimum number of yes/no questions required to determine exactly which god is which, and what is a strategy that guarantees success?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Answer in short:
# - The minimum number of yes/no questions is 3.
# - A concrete 3-question strategy (using embedded questions that neutralize the language issue and work for both the Truth-teller and the Liar) can guarantee identification of all three gods, regardless of which one is Random and regardless of whether “da” or “ja” means yes.
#
# Reason for the lower bound (why 3 are necessary):
# - There are 6 possible assignments of the three roles (Truth, Lie, Random to A, B, C).
# - A single yes/no question has at most 2 possible answers, and the Random god answers randomly, so information gathered from each answer is unreliable unless we restrict to non-random respondents.
# - With only 2 questions you cannot deterministically distinguish all 6 possibilities in all cases (especially when Random may be asked and give a meaningless answer). So at least 3 are required. It is known that 3 questions suffice (Boolos’ puzzle; Rabern & Rabern have a clean 3-question construction).
#
# A robust 3-question strategy (outline and explicit questions)
#
# Key tool: use questions of the form
# - U(X, P) = “If I asked you P, would you say ja?”
#
# Why this helps:
# - If X is Truth-teller or Liar (i.e., not Random), the answer to U(X, P) will be the word that corresponds to the truth value of P in X’s language: it will be the yes-word if P is true and the no-word if P is false, and crucially this result is obtained with a single answer that does not depend on whether ja means yes or no in X’s language.
# - If X is Random, the answer is irrelevant (random).
#
# The plan is to identify a non-random god and then finish by distinguishing Truth from Lie, using at most two more embedded questions. The questions below are given in a consistent form so that if you ask any non-random god, you can read off a true yes/no value from the response word (ja or da) without needing to know which word means yes.
#
# Question 1 (to A):
# - Ask A: U(A, "Is B Random?") i.e. “If I asked you ‘Is B Random?’, would you say ja?”
#
# Interpretation after Q1:
# - If A is non-random, the answer ja means “B is Random”; the answer da means “B is not Random.”
# - If A is Random, the answer is not informative; proceed to the next question.
#
# Question 2 (to a god you choose adaptively; the natural choice is to ask to B if you can, otherwise to C):
# - If you learned from Q1 that B is Random (and A was non-random, which is the typical branch you hope for), then you know B is Random and the other two are Truth and Lie. In that branch you can use a second embedded question to one of the non-random gods to determine which of the two remaining is Truth and which is Lie. For robustness, you can ask the following to A (who if not Random in this branch is non-random):
#   - Ask A: U(A, "Is C the Truth-teller?") i.e. “If I asked you ‘Is C the Truth-teller?’, would you say ja?”
# - If A answers ja, conclude that C is the Truth-teller; if A answers da, conclude that C is the Lie (in this branch). If you instead had B non-random in this branch, you would phrase this second question to B instead of A, but the same logic applies.
#
# - If Q1 did not yield B is Random (i.e., you got the opposite answer, or if A was Random so Q1 was inconclusive), proceed similarly by targeting another non-random pair. The essential point is: in any branch, you can select a non-random respondent and use an embedded question to identify which of the remaining two is Truth-teller vs Lie, while the third god’s identity (Random) has been determined by elimination.
#
# Question 3 (to a known non-random god from the above step, finishing the triple):
# - Ask that known non-random god the same embedded form about the remaining two:
#   - Example: If you have established that C is the Truth-teller in the previous step, ask A (the other non-random) U(A, "Is B the Random god?") or U(A, "Is C the Truth-teller?") depending on what remains to be resolved. The answer (ja or da) will tell you definitively which of the two remaining gods is Truth and which is Lie, because the embedded form ensures a non-random respondent answers the yes/no truth value (in the words ja/da) corresponding to the actual truth of the proposition.
#
# How the three questions do the job in all cases
# - If you ever end up asking a non-random god, the embedded form yields a true yes/no value (expressed as ja or da in that god’s language) for the proposition asked.
# - By choosing questions strategically (Is B Random?; Is C the Truth-teller?; Is A Random?), and switching to another non-random respondent when you encounter Random, you can:
#   - Identify which god is Random (by elimination, guided by the reliable non-random answers).
#   - Distinguish Truth from Lie among the remaining two non-Random gods (again using embedded questions so that their answers correspond to the truth value of the proposition, independent of language).
#   - Hence determine exactly which god is A, which is B, and which is C.
#
# Notes and practical tips
# - The exact three questions can be chosen in a few equivalent ways; the common, compact approach is to use the universal question U(X, P) to force a non-random respondent to yield a word that directly corresponds to the truth of P (ja if P is true, da if P is false, in that respondent’s language).
# - You do not need to know which word means yes or no in advance; the embedded form makes the yes/no content of P reflect in the word spoken, allowing you to identify the truth of P without knowing the mapping.
# - If you hit Random in a question, switch to another god for the next question. With three questions total, the plan is designed so that you can always get to a non-random and finish the job within those three questions.
#
# Bottom line
# - Minimum number of questions: 3.
# - Strategy: use embedded universal questions of the form “If I asked you P, would you say ja?” directed adaptively to non-random gods to extract truth-values of propositions about who is Random and who is Truth/ Lie, and finish with a final question that distinguishes Truth from Lie. This guarantees identification of all three gods in every possible assignment, despite the language ambiguity and the presence of the Random god.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Answer in short:
# - The minimum number of yes/no questions is 3.
# - A concrete 3-question strategy (using embedded questions that neutralize the language issue and work for both the Truth-teller and the Liar) can guarantee identification of all three gods, regardless of which one is Random and regardless of whether “da” or “ja” means yes.
#
# Reason for the lower bound (why 3 are necessary):
# - There are 6 possible assignments of the three roles (Truth, Lie, Random to A, B, C).
# - A single yes/no question has at most 2 possible answers, and the Random god answers randomly, so information gathered from each answer is unreliable unless we restrict to non-random respondents.
# - With only 2 questions you cannot deterministically distinguish all 6 possibilities in all cases (especially when Random may be asked and give a meaningless answer). So at least 3 are required. It is known that 3 questions suffice (Boolos’ puzzle; Rabern & Rabern have a clean 3-question construction).
#
# A robust 3-question strategy (outline and explicit questions)
#
# Key tool: use questions of the form
# - U(X, P) = “If I asked you P, would you say ja?”
#
# Why this helps:
# - If X is Truth-teller or Liar (i.e., not Random), the answer to U(X, P) will be the word that corresponds to the truth value of P in X’s language: it will be the yes-word if P is true and the no-word if P is false, and crucially this result is obtained with a single answer that does not depend on whether ja means yes or no in X’s language.
# - If X is Random, the answer is irrelevant (random).
#
# The plan is to identify a non-random god and then finish by distinguishing Truth from Lie, using at most two more embedded questions. The questions below are given in a consistent form so that if you ask any non-random god, you can read off a true yes/no value from the response word (ja or da) without needing to know which word means yes.
#
# Question 1 (to A):
# - Ask A: U(A, "Is B Random?") i.e. “If I asked you ‘Is B Random?’, would you say ja?”
#
# Interpretation after Q1:
# - If A is non-random, the answer ja means “B is Random”; the answer da means “B is not Random.”
# - If A is Random, the answer is not informative; proceed to the next question.
#
# Question 2 (to a god you choose adaptively; the natural choice is to ask to B if you can, otherwise to C):
# - If you learned from Q1 that B is Random (and A was non-random, which is the typical branch you hope for), then you know B is Random and the other two are Truth and Lie. In that branch you can use a second embedded question to one of the non-random gods to determine which of the two remaining is Truth and which is Lie. For robustness, you can ask the following to A (who if not Random in this branch is non-random):
#   - Ask A: U(A, "Is C the Truth-teller?") i.e. “If I asked you ‘Is C the Truth-teller?’, would you say ja?”
# - If A answers ja, conclude that C is the Truth-teller; if A answers da, conclude that C is the Lie (in this branch). If you instead had B non-random in this branch, you would phrase this second question to B instead of A, but the same logic applies.
#
# - If Q1 did not yield B is Random (i.e., you got the opposite answer, or if A was Random so Q1 was inconclusive), proceed similarly by targeting another non-random pair. The essential point is: in any branch, you can select a non-random respondent and use an embedded question to identify which of the remaining two is Truth-teller vs Lie, while the third god’s identity (Random) has been determined by elimination.
#
# Question 3 (to a known non-random god from the above step, finishing the triple):
# - Ask that known non-random god the same embedded form about the remaining two:
#   - Example: If you have established that C is the Truth-teller in the previous step, ask A (the other non-random) U(A, "Is B the Random god?") or U(A, "Is C the Truth-teller?") depending on what remains to be resolved. The answer (ja or da) will tell you definitively which of the two remaining gods is Truth and which is Lie, because the embedded form ensures a non-random respondent answers the yes/no truth value (in the words ja/da) corresponding to the actual truth of the proposition.
#
# How the three questions do the job in all cases
# - If you ever end up asking a non-random god, the embedded form yields a true yes/no value (expressed as ja or da in that god’s language) for the proposition asked.
# - By choosing questions strategically (Is B Random?; Is C the Truth-teller?; Is A Random?), and switching to another non-random respondent when you encounter Random, you can:
#   - Identify which god is Random (by elimination, guided by the reliable non-random answers).
#   - Distinguish Truth from Lie among the remaining two non-Random gods (again using embedded questions so that their answers correspond to the truth value of the proposition, independent of language).
#   - Hence determine exactly which god is A, which is B, and which is C.
#
# Notes and practical tips
# - The exact three questions can be chosen in a few equivalent ways; the common, compact approach is to use the universal question U(X, P) to force a non-random respondent to yield a word that directly corresponds to the truth of P (ja if P is true, da if P is false, in that respondent’s language).
# - You do not need to know which word means yes or no in advance; the embedded form makes the yes/no content of P reflect in the word spoken, allowing you to identify the truth of P without knowing the mapping.
# - If you hit Random in a question, switch to another god for the next question. With three questions total, the plan is designed so that you can always get to a non-random and finish the job within those three questions.
#
# Bottom line
# - Minimum number of questions: 3.
# - Strategy: use embedded universal questions of the form “If I asked you P, would you say ja?” directed adaptively to non-random gods to extract truth-values of propositions about who is Random and who is Truth/ Lie, and finish with a final question that distinguishes Truth from Lie. This guarantees identification of all three gods in every possible assignment, despite the language ambiguity and the presence of the Random god.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "What is one business area that has an opportunity for agentic AI automation?"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=messages,
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Customer service and support.
#
# Reason: Agentic AI can autonomously triage inquiries, pull account or order data from CRM and backend systems, perform actions (e.g., reset passwords, update records, process refunds), escalate complex issues, and schedule follow-ups. This can improve response times, first-contact resolution, and reduce manual workload while learning from interactions.

# %%
messages = [{"role": "user", "content": f"Please present an agentic AI solution to the following business problem: {business_idea}"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=messages,
)

# Then read the business idea:

business_solution = response.choices[0].message.content
print(business_solution)
# Out:
# Below is a practical, end-to-end agentic AI solution tailored to a customer service and support problem. It emphasizes autonomous triage and actions while maintaining safety, governance, and measurable business value.
#
# 1) Objective and Scope
# - Goal: Improve response times, increase first-contact resolution (FCR), reduce manual workload, and continuously learn from interactions.
# - Capabilities: Autonomously triage inquiries, fetch data from CRM/ERP, perform safe actions (e.g., reset passwords, update records, process refunds), escalate complex issues to humans, and schedule follow-ups.
# - Boundaries: High-risk actions require human-in-the-loop approval or strict controls; user authentication is required before sensitive actions; thorough audit trails and explainability for all actions.
#
# 2) Target Outcomes and Metrics
# - Operational metrics: Average Handling Time (AHT), FCR rate, first-response time, SLA adherence, escalation rate, refunds processed without human touch rate.
# - Customer metrics: CSAT, NPS, sentiment trend, resolution time.
# - Efficiency metrics: Agent time savings, deflected tickets, automation accuracy, action success rate.
# - Learning feedback: Continuous improvement signals from closed-loop outcomes (e.g., refunds approved without changes vs. after escalation).
#
# 3) High-level Architecture (textual)
# - Channels: Chat, voice-to-text, email, mobile app, web widget.
# - Orchestration Layer: Central agent controller that routes inquiries, manages state, and coordinates actions.
# - Core AI Agent (Agentic Core): A decision engine built on an LLM with tool-plugins and a policy layer.
# - Tooling & Integrations (back-end connectors):
#   - CRM/ERP: Pull and update account details, orders, tickets (e.g., Salesforce, Zendesk, SAP, Oracle).
#   - Identity & Security: Authenticate users, enable password resets, MFA checks.
#   - Payments & Refunds: Process refunds, adjust billing (e.g., Stripe, internal billing system).
#   - Knowledge Base: Retrieve articles, verify resolutions, publish updates.
#   - Ticketing & Workflow: Create or update service tickets, assign to human agents, schedule follow-ups.
#   - Scheduling: Calendar for callbacks and follow-ups.
#   - Audit & Logging: Immutable logs of actions, decision rationales, and user consent.
# - Data Stores:
#   - Customer profile, orders, tickets, and interaction history (CRM/ERP).
#   - Action and decision logs (audit store).
#   - Knowledge base index (vector store for retrieval).
# - Observability & Governance:
#   - Monitoring dashboards, alerting, error handling, rate limiting.
#   - Compliance controls: data minimization, retention policies, access controls, explainability.
#   - Privacy protection: PII redaction, data masking, and least-privilege access.
#
# 4) Agent Capabilities and Decision Model
# - Triage and Intent Classification:
#   - Classify request type (password reset, order issue, refund, update contact info, billing question, technical support, etc.).
#   - Determine urgency and potential risk (security risk, potential fraud, data exposure).
# - Data Retrieval:
#   - Pull relevant data from CRM/ERP (account status, recent orders, recent interactions, entitlement, payment status).
# - Action Primitives (safe, composable building blocks):
#   - GetAccountDetails(customer_id)
#   - GetOrderDetails(order_id or last N orders)
#   - ResetPassword(user_identity, method)
#   - UpdateRecord(record_type, record_id, fields)
#   - CreateRefund(order_id, amount, reason)
#   - ScheduleFollowUp(customer_id, contact_method, timeslot)
#   - CreateTicketOrUpdateTicket(ticket_id, updates)
#   - EscalateToHuman(reason, summary, attached data)
#   - RetrieveKnowledgeArticle(query) and RecommendResolution
# - Decision-Energy (policy layer):
#   - Confidence scoring for each proposed action.
#   - Safety checks (auth, consent, data sensitivity).
#   - Thresholds to auto-execute vs. require human approval.
#   - Default to escalate for high-risk or ambiguous cases.
# - Explainability and Transparency:
#   - Provide a concise rationale for actions taken and decisions to the user and the agent.
#   - Maintain an auditable chain of decisions and data used.
#
# 5) Typical Workflows (example end-to-end)
# - Workflow A: Self-service Password Reset
#   - User: “I forgot my password.”
#   - System: Verifies user identity (SSO/M2M or challenge questions with consent).
#   - Action: ResetPassword(user_identity, via_email_to_secured_link) or reset in-app if strong authentication passed.
#   - Conclude: Confirm reset method, provide next steps, log actions, and schedule a follow-up if needed.
# - Workflow B: Refund for a Recent Purchase
#   - User: “I wasn’t satisfied with my order.”
#   - System: Retrieve order details, verify eligibility, check return window, detect refund rules.
#   - Action: CreateRefund(order_id, amount, reason). If amount requires confirmation, escalate to human with summary.
#   - Conclude: Notify user of outcome, update order/status, log audit data.
# - Workflow C: Complex Issue – Escalation with Summary
#   - User: Reports recurring issue with a product.
#   - System: Pulls recent tickets and logs, checks knowledge base for potential resolution.
#   - Decision: If resolution uncertain or pattern detected, escalate to human with a summarized context, relevant data, and suggested next steps.
#   - Conclude: A human agent is assigned; user is notified of escalation and expected response time.
#
# 6) Safety, Security, and Compliance
# - Autonomy safeguards:
#   - Action thresholds: Most actions executed automatically only if confidence > a defined threshold and no PII exposure risk.
#   - High-risk actions require human approval (e.g., large refunds, password resets after multiple failed attempts, changes to billing or ownership).
#   - Requirement for customer authentication before sensitive actions.
# - Data privacy and minimization:
#   - Use only necessary data; redact PII in agent explanations unless user is authorized.
#   - Encrypt data in transit and at rest; rotate credentials; least-privilege access controls.
#   - Data retention aligned with policy; automatic purge or archival after retention period.
# - Auditability and explainability:
#   - Immutable logs of each action, data accessed, and rationale.
#   - Ability to generate a user-understandable summary of what the agent did and why.
# - Compliance:
#   - PCI-DSS considerations for payment-related actions; HIPAA or regional privacy rules as applicable.
#   - Data localization and cross-border data handling per policy.
# - Fraud and abuse prevention:
#   - Behavioral anomaly detection (e.g., unusual refund requests, atypical authentication patterns).
#   - Rate limiting and bot-detection for non-human interactions.
#
# 7) Data and Integrations in Detail
# - CRM/ERP integrations:
#   - Read: account status, eligibility, order histories, entitlements.
#   - Write: update contact info, close tickets, log interactions, adjust orders, issue refunds or credits, reset security credentials.
# - Knowledge Base:
#   - Real-time retrieval of articles; if unresolved, capture user questions and feed to the agent for human follow-up.
# - Authentication and Identity:
#   - OIDC/OAuth for service-to-service calls; user verification before actions.
# - Payment Systems:
#   - Refunds and billing changes go through secure payment gateways; require authorization and fraud checks.
# - Ticketing and Workflow:
#   - Create/update tickets; assign to human agents with context; auto-schedule follow-ups.
# - Observability:
#   - Telemetry on response times, action success/failure, and model confidence.
#
# 8) UX and Dialog Design
# - User-facing flow:
#   - Clear intent extraction and confirmation prompts.
#   - Offer self-service options and explain expected outcome.
#   - If uncertain, propose escalation with a brief summary and expected ETA.
# - System prompts:
#   - Provide concise rationales for actions.
#   - Allow user to modify or cancel actions at any point.
# - Human handoff:
#   - When escalating, automatically attach context, recent interactions, and data pulled from systems to streamline the agent handoff.
#
# 9) Data Model and Artifacts (conceptual)
# - CustomerProfile: id, name, contact, authentication methods, preferences.
# - Interaction: conversation_id, channel, timestamp, user_message, agent_message, actions_taken, data_accessed.
# - ActionLog: action_id, action_type, target_object (record_type, id), before_state, after_state, outcome, confidence, approval_required, approver_id.
# - KnowledgeQueue: article_id, query, relevance_score, used_in_resolution.
# - Tickets: ticket_id, customer_id, issue_summary, status, priority, assigned_agent, SLA_due.
# - AuditTrail: cryptographically signed entries for compliance.
#
# 10) Implementation Plan (phased)
# - Phase 1: Foundation and Safety
#   - Select pilot use cases (password reset, order status inquiries, simple refunds under low amount).
#   - Establish identity verification, authorization rules, and audit architecture.
#   - Integrate core CRM and ticketing systems; configure data access controls.
#   - Define KPIs and success criteria; create monitoring dashboards.
# - Phase 2: Pilot Deployment
#   - Deploy agent in a limited channel (chat on web/app) with a soft handoff to humans for escalations.
#   - Validate action accuracy, latency, and customer satisfaction.
#   - Refine prompts, decision thresholds, and escalation policies.
# - Phase 3: Scale and Expand
#   - Add more use cases (billing questions, order changes, account updates).
#   - Extend to voice channels with ASR/NLU capabilities.
#   - Implement advanced fraud detection and stronger risk thresholds.
# - Phase 4: Optimize and Learn
#   - Continuously retrain the model on new data; monitor drift and performance.
#   - Introduce self-healing actions where safe; enhance knowledge base with frequent issues.
#   - Strengthen governance: periodic reviews, audits, and policy updates.
#
# 11) Technology Stack (illustrative)
# - LLM and reasoning:
#   - Core model: large language model fine-tuned for support scenarios (e.g., GPT-4 family or equivalent).
#   - Retrieval: RAG with a vector store (embedding-based search over knowledge base and past tickets).
# - Orchestration and tools:
#   - API gateway and an action broker that enforces policy and executes action primitives.
#   - Workflow engine or event-driven architecture (e.g., asynchronous queues, state machine for multi-step actions).
# - Integrations:
#   - CRM/ERP connectors (Salesforce, Zendesk, SAP, Oracle, NetSuite).
#   - Identity and security services (OAuth, SSO, MFA, token vault).
#   - Payment gateway connectors (Stripe, Adyen) for refunds.
#   - Knowledge base repository and CMS.
# - Data & security:
#   - Relational/NoSQL databases for profiles and logs.
#   - Encrypted storage, access controls, and audit logging.
#   - Observability: APM, log aggregation, metrics dashboards.
# - Governance and compliance:
#   - Data retention policies, role-based access control, model risk management tooling.
#
# 12) Risk, Mitigations, and Contingencies
# - Autonomy risk: Low confidence in actions could lead to harmful changes.
#   - Mitigation: Use conservative confidence thresholds; require user confirmation for ambiguous actions; require human sign-off for high-risk actions.
# - Data privacy: PII exposure through logs or explanations.
#   - Mitigation: Redact PII in user-visible explanations; minimize data surfaced in agent messages; strict access controls.
# - System outages: Dependencies on CRM or payments services.
#   - Mitigation: Circuit breakers; retries with backoff; fallback to manual routing.
# - Compliance drift: Changes in policy or regional rules.
#   - Mitigation: Policy-as-code; periodic audits; changelog and impact assessment for each update.
# - Model errors and drift:
#   - Mitigation: Continuous monitoring of accuracy and automation rate; rollback plan; human-in-the-loop for outliers.
#
# 13) Example Prompts and Intent Examples (for reference)
# - Intent: Password reset
#   - Prompt: “I’d like to reset my password. Please verify my identity and proceed if allowed.”
#   - Agent behavior: Validate identity, call ResetPassword, confirm with user, log actions.
#
# - Intent: Refund processing
#   - Prompt: “I want a refund for my recent order.”
#   - Agent behavior: Retrieve order, check eligibility, propose amount, request confirmation, process or escalate as needed.
#
# - Intent: Update contact details
#   - Prompt: “Update my phone number.”
#   - Agent behavior: Verify permission, update CRM record, confirm success.
#
# - Intent: Complex product issue
#   - Prompt: “I’ve had recurring issues with product X after version Y.”
#   - Agent behavior: Pull recent tickets, searches KB, summarize findings, escalate with context to human agent.
#
# 14) Operational Readiness Checklist
# - Data readiness: Clean and map data fields needed for key workflows; ensure data quality in CRM/ERP.
# - Security & privacy: Implement PII handling policy, encryption, access controls, and audit logging.
# - Compliance: Align with applicable data protection laws and industry regulations.
# - Change management: Train human agents on how the agent works, its capabilities, and escalation flows.
# - Customer communication: Inform customers that some inquiries can be handled by an AI agent and how they can opt out.
#
# 15) What Success Looks Like
# - Faster first response and reduced average handling time.
# - Higher FCR and fewer escalations for routine issues.
# - Measurable lift in CSAT and NPS for areas covered by automation.
# - Lower manual workload for human agents enabling them to focus on complex tasks.
# - A robust feedback loop that continuously improves recommendations and actions.
#
# If you’d like, I can tailor this to your exact stack (CRM name, payment provider, knowledge base system), draft a phased implementation plan with concrete milestones, and provide a reference data schema and example API contracts for the action primitives.
